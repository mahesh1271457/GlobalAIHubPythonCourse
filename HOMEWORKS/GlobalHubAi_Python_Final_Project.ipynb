# %%
class employee:
      def __init__(self):
            self.empname=input("Enter employee name :")
            self.emp1age=input("Enter employee age :")
            self.emp2lang=input("Enter employee language:")
            self.emp3name=input("Enter 2nd employee name :")
            self.emp1age=input("Enter  2nd employee age :")
            self.emp2lang=input("Enter 2nd employee language:")
           
      def display(self):
            print("employee name:",self.empname)
            print("employee age:",self.emp1age)
            print("employee language:",self.emp2lang)
            
class manager:
      def __init__(self):
            self.mangname=input("Enter manager name:")
            self.mang1age=input("Enter manager age:")
            self.mang2lang=input("Enter  manager language:")
            self.mangname=input("Enter manager name:")
            self.mang1age=input("Enter manager age:")
            self.mang2lang=input("Enter manager language:")
            
      def display(self):
            print("entermanager name:",self.mangname)
            print("enter manager age:",self.mang1age)
            print("enter manager language:",self.mang2lang)
            print("enter 2ndmanager name:",self.mangname)
            print("enter manager 2nd age:",self.mang1age)
            print("enter manager 2nd language:",self.mang2lang)
            
class emp(employee):
    def __init__(self):
            employee.__init__(self)
          #  self.mang1age=input("Enter language:")
    def display(self):
            employee.display(self)
       #     print("employee name:",self.name)

class mang(manager):
      def __init__(self):
            manager.__init__(self)
            self.mang1age=input("Enter language:")
      def display(self):
            manager.display(self)
            #print("manager name:",self.name)

while 1:
      print("Enter your choice")
      print("1.enter the details 2.Exit")
      n=int(input())
      if n==1:
            single=emp()
            single1=mang()
            single.display()
            single1.display()
            print(employee,manager)
      elif n==2:
            break
      else:
            print("Invalid choice")
# Out:
# Enter your choice
# 1.enter the details 2.Exit
# 1
# Enter employee name :mahesh
# Enter employee age :21
# Enter employee language:english
# Enter 2nd employee name :kumar
# Enter  2nd employee age :22
# Enter 2nd employee language:hindi
# Enter manager name:ravi
# Enter manager age:24
# Enter  manager language:telugu
# Enter manager name:kishore
# Enter manager age:32
# Enter manager language:english
# Enter language:english
# employee name: mahesh
# employee age: 22
# employee language: hindi
# entermanager name: kishore
# enter manager age: english
# enter manager language: english
# enter 2ndmanager name: kishore
# enter manager 2nd age: english
# enter manager 2nd language: english
# <class '__main__.employee'> <class '__main__.manager'>
# Enter your choice
# 1.enter the details 2.Exit
# 2
